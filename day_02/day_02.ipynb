# %%
 # data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd
import math

 # visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

train_df = pd.read_csv('data/train_longevity.csv')
test_df = pd.read_csv('data/test_longevity.csv')
combine = [train_df, test_df]

# %%
#Задание 1: Признак Age должен быть дополнен и фильтрован для обработки алгоритмами.

#Удаление некорректных значений:
idmax = train_df['Age'].value_counts().idxmax()
train_df['Age'] = train_df['Age'].map(lambda v: idmax if v == '#ЗНАЧ!' else v).astype(float)
test_df['Age'] = train_df['Age'].map(lambda v: idmax if v == '#ЗНАЧ!' else v).astype(float)

#Среднее значение столбца Age
avg_train = train_df['Age'].mean()
avg_test = test_df['Age'].mean()

train_df['Age'] = train_df['Age'].map(lambda x: avg_train if math.isnan(x) else x)
test_df['Age'] = test_df['Age'].map(lambda x: avg_test if math.isnan(x) else x)
train_df
# Out:
#       Id  Longevity  Education     Sex        Age  Pet  Children       Region  \
# 0      1          0          3  female  73.000000    1         0           21
# 1      2          1          1    male  75.000000    1         0           17
# 2      3          1          3    male  73.000000    0         0           31
# 3      4          1          1    male  74.000000    1         0           11
# 4      5          0          3  female  74.000000    0         0           37
# 5      6          0          3  female  73.797059    0         0           33
# 6      7          0          1  female  77.000000    0         0           17
# 7      8          0          3  female  70.000000    3         1           34
# 8      9          1          3    male  73.000000    0         2           34
# 9     10          1          2    male  72.000000    1         0           23
# 10    11          1          3    male  71.000000    1         1           95
# ...

# %%
#Задание 2: Признак MedExam может быть отброшен, поскольку является крайне неполным 
#или содержит много нулевых значений как в обучающем, так и в тестовом наборе данных.

train_df = train_df.drop(['MedExam'], axis='columns')
test_df = test_df.drop(['MedExam'], axis='columns')
test_df
# Out:
#        Id  Education     Sex        Age  Pet  Children  Region  Activity  \
# 0     858          1  female  73.000000    0         0    11.0      2655
# 1     859          3    male  75.000000    0         3    26.0      1926
# 2     860          3  female  73.000000    0         0    26.0       723
# 3     861          3  female  74.000000    2         0    35.0      1411
# 4     862          2  female  74.000000    1         0    28.0      1150
# 5     863          1    male  73.649171    0         0    17.0      2593
# 6     864          3    male  77.000000    8         2    23.0      6955
# 7     865          2  female  70.000000    0         0    23.0      1300
# 8     866          2    male  73.000000    0         0    23.0      1300
# 9     867          2    male  72.000000    1         0    21.0      1386
# 10    868          1  female  71.000000    0         0    17.0      5050
# 11    869          3  female  77.000000    0         0    34.0       950
# ...

# %%
#Задание 3: Необходимо дополнить функцию Sport, 
#поскольку она также может соотноситься с долголетием.

def sport_indication(activity, avg_activity, atr):
    if atr != '+' and atr != '-':
        if activity >= avg_activity:
            return '+'
        return '-'
    return atr

avg_activity_train = train_df['Activity'].mean()
avg_activity_test = test_df['Activity'].mean()

train_df['Sport'] = train_df.apply(lambda x: sport_indication(x['Activity'], avg_activity_train, x['Sport']), axis = 1)
train_df
test_df['Sport'] = test_df.apply(lambda x: sport_indication(x['Activity'], avg_activity_test, x['Sport']), axis = 1)
test_df
# Out:
#        Id  Education     Sex        Age  Pet  Children  Region  Activity  \
# 0     858          1  female  73.000000    0         0    11.0      2655
# 1     859          3    male  75.000000    0         3    26.0      1926
# 2     860          3  female  73.000000    0         0    26.0       723
# 3     861          3  female  74.000000    2         0    35.0      1411
# 4     862          2  female  74.000000    1         0    28.0      1150
# 5     863          1    male  73.649171    0         0    17.0      2593
# 6     864          3    male  77.000000    8         2    23.0      6955
# 7     865          2  female  70.000000    0         0    23.0      1300
# 8     866          2    male  73.000000    0         0    23.0      1300
# 9     867          2    male  72.000000    1         0    21.0      1386
# 10    868          1  female  71.000000    0         0    17.0      5050
# 11    869          3  female  77.000000    0         0    34.0       950
# ...

# %%
#Задание 4: Признак Region может быть исключен из нашего анализа, так как содержит 
#большое количество дубликатов (22%) и может отсутствовать корреляция между ним и целевым признаком.

train_df = train_df.drop(['Region'], axis='columns')
test_df = test_df.drop(['Region'], axis='columns')
train_df
# Out:
#       Id  Longevity  Education     Sex        Age  Pet  Children  Activity  \
# 0      1          0          3  female  73.000000    1         0       725
# 1      2          1          1    male  75.000000    1         0      7128
# 2      3          1          3    male  73.000000    0         0       793
# 3      4          1          1    male  74.000000    1         0      5310
# 4      5          0          3  female  74.000000    0         0       805
# 5      6          0          3  female  73.797059    0         0       846
# 6      7          0          1  female  77.000000    0         0      5186
# 7      8          0          3  female  70.000000    3         1      2108
# 8      9          1          3    male  73.000000    0         2      1113
# 9     10          1          2    male  72.000000    1         0      3007
# 10    11          1          3    male  71.000000    1         1      1670
# ...

# %%
#Задание 5: Признак Id может быть удален из набора обучающих данных, 
#поскольку он не способствует целевому признаку Longevity

train_df = train_df.drop(['Id'], axis='columns')
train_df
# Out:
#      Longevity  Education     Sex        Age  Pet  Children  Activity Sport
# 0            0          3  female  73.000000    1         0       725     -
# 1            1          1    male  75.000000    1         0      7128     +
# 2            1          3    male  73.000000    0         0       793     -
# 3            1          1    male  74.000000    1         0      5310     +
# 4            0          3  female  74.000000    0         0       805     -
# 5            0          3  female  73.797059    0         0       846     -
# 6            0          1  female  77.000000    0         0      5186     +
# 7            0          3  female  70.000000    3         1      2108     -
# 8            1          3    male  73.000000    0         2      1113     -
# 9            1          2    male  72.000000    1         0      3007     +
# 10           1          3    male  71.000000    1         1      1670     -
# ...

# %%
#Задание 6: Cоздать новый признак под названием Family 
#(Семья на основе детей и домашних животных), чтобы получить
#общее количество членов семьи.

train_df['Family'] = train_df.apply(lambda x: x['Children'] + x['Pet'], axis = 1)
test_df['Family'] = test_df.apply(lambda x: x['Children'] + x['Pet'], axis = 1)
train_df
# Out:
#      Longevity  Education     Sex        Age  Pet  Children  Activity Sport  \
# 0            0          3  female  73.000000    1         0       725     -
# 1            1          1    male  75.000000    1         0      7128     +
# 2            1          3    male  73.000000    0         0       793     -
# 3            1          1    male  74.000000    1         0      5310     +
# 4            0          3  female  74.000000    0         0       805     -
# 5            0          3  female  73.797059    0         0       846     -
# 6            0          1  female  77.000000    0         0      5186     +
# 7            0          3  female  70.000000    3         1      2108     -
# 8            1          3    male  73.000000    0         2      1113     -
# 9            1          2    male  72.000000    1         0      3007     +
# 10           1          3    male  71.000000    1         1      1670     -
# ...

# %%
#Задание 7: Создать новый признак IsAlone, проживающих одиноко без домашних животных и родственников.

train_df['IsAlone'] = train_df.apply(lambda x: 1 if not x['Family'] else 0, axis = 1)
test_df['IsAlone'] = test_df.apply(lambda x: 1 if not x['Family'] else 0, axis = 1)
train_df
# Out:
#      Longevity  Education     Sex        Age  Pet  Children  Activity Sport  \
# 0            0          3  female  73.000000    1         0       725     -
# 1            1          1    male  75.000000    1         0      7128     +
# 2            1          3    male  73.000000    0         0       793     -
# 3            1          1    male  74.000000    1         0      5310     +
# 4            0          3  female  74.000000    0         0       805     -
# 5            0          3  female  73.797059    0         0       846     -
# 6            0          1  female  77.000000    0         0      5186     +
# 7            0          3  female  70.000000    3         1      2108     -
# 8            1          3    male  73.000000    0         2      1113     -
# 9            1          2    male  72.000000    1         0      3007     +
# 10           1          3    male  71.000000    1         1      1670     -
# ...

# %%
#Задание 8: Cоздать новый признак для возрастных групп (Age,Education), 
#указывающий на социальный статус пожилого человека. 
#Это превращает непрерывный числовой признак в порядковый категориальный признак

#Education = 1 => Elite
#Education = 2 => Wealthy Middle Class
#Education = 3 => Work Class
def get_status(age, education):
    if education == 1:
        return 1
    if education == 2:
        return 2
    if education == 3:
        return 3
train_df['Status'] = train_df.apply(lambda x: get_status(x['Age'], x['Education']), axis = 1)
test_df['Status'] = test_df.apply(lambda x: get_status(x['Age'], x['Education']), axis = 1)
train_df
# Out:
#      Longevity  Education     Sex        Age  Pet  Children  Activity Sport  \
# 0            0          3  female  73.000000    1         0       725     -
# 1            1          1    male  75.000000    1         0      7128     +
# 2            1          3    male  73.000000    0         0       793     -
# 3            1          1    male  74.000000    1         0      5310     +
# 4            0          3  female  74.000000    0         0       805     -
# 5            0          3  female  73.797059    0         0       846     -
# 6            0          1  female  77.000000    0         0      5186     +
# 7            0          3  female  70.000000    3         1      2108     -
# 8            1          3    male  73.000000    0         2      1113     -
# 9            1          2    male  72.000000    1         0      3007     +
# 10           1          3    male  71.000000    1         1      1670     -
# ...

# %%
#Задание 9: Cоздать новый признак диапазонов возрасного равновесия на основе признака Age, 
#т.к. это поможет разделить пожилых людей на группы условно равновесного состояния 
#(смертность повышается в определенные периоды времени между 70 и 80 годами,
#и в другие моменты резко снижается) для следующих интервалов: 
#{ (...,70](70,72],(72,74],(74,76],(76,78],(80,..)}

def get_diapason(age):
    if age <= 70:
        return 1
    if age > 70 and age <= 72:
        return 2
    if age > 72 and age <= 74:
        return 3
    if age > 74 and age <= 76:
        return 4
    if age > 76 and age <= 78:
        return 5
    return 6
train_df['AgeDiapason'] = train_df.apply(lambda x: get_diapason(x['Age']), axis = 1)
test_df['AgeDiapason'] = test_df.apply(lambda x: get_diapason(x['Age']), axis = 1)
train_df
# Out:
#      Longevity  Education     Sex        Age  Pet  Children  Activity Sport  \
# 0            0          3  female  73.000000    1         0       725     -
# 1            1          1    male  75.000000    1         0      7128     +
# 2            1          3    male  73.000000    0         0       793     -
# 3            1          1    male  74.000000    1         0      5310     +
# 4            0          3  female  74.000000    0         0       805     -
# 5            0          3  female  73.797059    0         0       846     -
# 6            0          1  female  77.000000    0         0      5186     +
# 7            0          3  female  70.000000    3         1      2108     -
# 8            1          3    male  73.000000    0         2      1113     -
# 9            1          2    male  72.000000    1         0      3007     +
# 10           1          3    male  71.000000    1         1      1670     -
# ...
